# %% [markdown]
# # Empyrial playground

# %%
from empyrial import empyrial, Engine
import yfinance as yf

# %% [markdown]
# ## Access orderbook
#
# run the EF backtest and get the weights from the orderbook. Take the weights from the orderbook and use them in the Calandar rebalancing

# %%
from empyrial import empyrial, Engine

portfolio = Engine(
      start_date = "2020-01-01",
      portfolio = ['TSLA','ETH-USD','BTC-USD','AVAX-USD','MATIC-USD', 'DOT-USD','COIN','XRP-USD','ARKK','AMZN','USD',],
      optimizer = "EF",
      rebalance = "1y", #rebalance every year
      min_weights = 0.05, 
      max_weights = 0.35
)

empyrial(portfolio)

empyrial.orderbook
# Out:
# 1 Failed download:
# - COIN: Data doesn't exist for startDate = 1577854800, endDate = 1609390800
#
# 1 Failed download:
# - COIN: Data doesn't exist for startDate = 1577854800, endDate = 1609390800
# Start date: 2020-01-01
# End date: 2023-08-02
#                                  Backtest
#
# Annual return                     100.11%
# Cumulative return                3572.33%
# Annual volatility                 68.84 %
# Winning day ratio                  55.23%
# Sharpe ratio                         1.35
# Calmar ratio                          2.2
# Information ratio                    0.01
# Stability                            0.61
# Max Drawdown                     -78.87 %
# Sortino ratio                        2.15
# Skew                                 0.67
# Kurtosis                             6.79
# Tail Ratio                           1.15
# Common sense ratio                   1.49
# Daily value at risk  -7.000000000000001 %
# Alpha                                1.82
# Beta                                 1.33
#            2020-12-31  2021-12-31  2022-12-31  2023-08-02
# TSLA             0.05        0.05        0.05        0.05
# ETH-USD          0.20        0.05        0.05        0.20
# BTC-USD          0.05        0.05        0.05        0.05
# AVAX-USD         0.05        0.20        0.20        0.05
# MATIC-USD        0.05        0.35        0.35        0.35
# DOT-USD          0.35        0.05        0.05        0.05
# COIN             0.05        0.05        0.05        0.05
# XRP-USD          0.05        0.05        0.05        0.05
# ARKK             0.05        0.05        0.05        0.05
# AMZN             0.05        0.05        0.05        0.05
# USD              0.05        0.05        0.05        0.05

# %% [markdown]
# ## Calendar Rebalancing

# %%
# Copy the results from the order book, paste them in excel and transform them from column to row. Copy the rows and paste the values in the 
# first_row and second_row variables below and run this script to get properly formatted portfolio and weights. 
# copy the output and paste in the balancing below 
first_row = "TSLA ETH-USD BTC-USD AVAX-USD MATIC-USD DOT-USD COIN XRP-USD ARKK AMZN USD"
second_row = "0.05 0.05 0.05 0.2 0.35 0.05 0.05 0.05 0.05 0.05 0.05"

first_row = [f"{ticker}" for ticker in first_row.split()]

second_row = [float(x) for x in second_row.split()]

print(first_row)
print(second_row)
# Out:
# ['TSLA', 'ETH-USD', 'BTC-USD', 'AVAX-USD', 'MATIC-USD', 'DOT-USD', 'COIN', 'XRP-USD', 'ARKK', 'AMZN', 'USD']
# [0.05, 0.05, 0.05, 0.2, 0.35, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

# %%
from empyrial import empyrial, Engine

portfolio = Engine(    
       start_date= "2018-06-09", 
       portfolio= ['TSLA', 'ETH-USD', 'BTC-USD', 'AVAX-USD', 'MATIC-USD', 'DOT-USD', 'COIN', 'XRP-USD', 'ARKK', 'AMZN', 'USD'], 
		   weights = [0.05, 0.05, 0.05, 0.2, 0.35, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05], #equal weighting is set by default
       benchmark = ["SPY"], #SPY is set by default
		   rebalance = "1y" #rebalance every year
)

empyrial(portfolio)
# Out:
# 3 Failed downloads:
# - AVAX-USD: Data doesn't exist for startDate = 1528516800, endDate = 1560052800
# - COIN: Data doesn't exist for startDate = 1528516800, endDate = 1560052800
# - DOT-USD: Data doesn't exist for startDate = 1528516800, endDate = 1560052800
#
# 3 Failed downloads:
# - COIN: Data doesn't exist for startDate = 1560052800, endDate = 1591588800
# - AVAX-USD: Data doesn't exist for startDate = 1560052800, endDate = 1591588800
# - DOT-USD: Data doesn't exist for startDate = 1560052800, endDate = 1591588800
# Start date: 2018-06-09
# End date: 2023-08-03
#                      Backtest
#
# Annual return          63.22%
# Cumulative return    3767.52%
# Annual volatility     63.67 %
# Winning day ratio      52.18%
# Sharpe ratio             1.08
# Calmar ratio             1.31
# Information ratio         0.0
# Stability                0.82
# Max Drawdown         -78.92 %
# Sortino ratio            1.71
# Skew                     0.67
# Kurtosis                 8.81
# Tail Ratio               1.19
# Common sense ratio       1.47
# Daily value at risk    -6.0 %
# Alpha                    1.09
# Beta                     1.29
# (None, None, None, None, None, None, None, None, None)

# %% [markdown]
# ## Custom Allocation

# %%
from empyrial import empyrial, Engine

portfolio = Engine(
      start_date = "2018-01-01",
      # portfolio = ['TSLA','ETH-USD','BTC-USD','USD',],
      portfolio = ['TSLA','ETH-USD','BTC-USD','AVAX-USD','MATIC-USD', 'DOT-USD','COIN','XRP-USD','ARKK','AMZN','USD',],      
      weights = [0.25, 0.1, 0.1, 0.1, 0.1, 0.05, 0.05, 0.05, 0.05, 0.05, 0.1 ], #custom weights
)

empyrial(portfolio)
# Out:
# Start date: 2018-01-01
# End date: 2023-08-02
#                      Backtest
#
# Annual return          39.96%
# Cumulative return    1415.99%
# Annual volatility      42.8 %
# Winning day ratio      54.32%
# Sharpe ratio              1.0
# Calmar ratio             0.88
# Information ratio         0.0
# Stability                0.82
# Max Drawdown         -71.24 %
# Sortino ratio            1.45
# Skew                    -0.23
# Kurtosis                 6.19
# Tail Ratio               1.12
# Common sense ratio       1.35
# Daily value at risk    -4.0 %
# Alpha                    0.43
# Beta                     1.37
# (None, None, None, None, None, None, None, None, None)

# %% [markdown]
# ## Mean Variance

# %%
from empyrial import empyrial, Engine

portfolio = Engine(    
       start_date= "2020-06-09", 
       benchmark = ["SPY"], #SPY is set by default
       portfolio= ["BABA", "AAPL", "KO", "^DJI","^IXIC", "TSLA",], 
      # portfolio = ['TSLA','ETH-USD','BTC-USD','AVAX-USD','MATIC-USD', 'DOT-USD','COIN','XRP-USD','ARKK','AMZN','USD',],
       optimizer = "MEANVAR", # defines Mean-Variance as the optimizer
       max_vol = 0.25, #maximize the return for this level of volatility (25%)              
)

empyrial(portfolio)
# Out:
# Start date: 2020-06-09
# End date: 2023-08-02
#                      Backtest
#
# Annual return          18.89%
# Cumulative return      72.12%
# Annual volatility     25.15 %
# Winning day ratio      52.21%
# Sharpe ratio             0.81
# Calmar ratio             0.65
# Information ratio         0.0
# Stability                0.11
# Max Drawdown         -29.08 %
# Sortino ratio            1.18
# Skew                    -0.05
# Kurtosis                 1.92
# Tail Ratio               0.95
# Common sense ratio       1.09
# Daily value at risk    -3.0 %
# Alpha                    0.04
# Beta                     1.14
# (None, None, None, None, None, None, None, None, None)

# %% [markdown]
# ## EF

# %%
portfolio = Engine(
      start_date = "2018-01-01",
      benchmark = ["SPY"], #SPY is set by default
      # portfolio = ['TSLA','ETH-USD','BTC-USD','USD',],
      portfolio = ['TSLA','ETH-USD','BTC-USD','AVAX-USD','MATIC-USD', 'DOT-USD','COIN','XRP-USD','ARKK','AMZN','USD',],
      optimizer = "EF",
      min_weights = 0.05, #invest at least 5% of the capital in every assets
      max_weights = 0.35 #don't invest more than 35% in one asset
)

empyrial(portfolio)
# Out:
# Start date: 2018-01-01
# End date: 2023-08-02
#                     Backtest
#
# Annual return          27.8%
# Cumulative return    627.78%
# Annual volatility    51.71 %
# Winning day ratio     52.57%
# Sharpe ratio            0.73
# Calmar ratio            0.52
# Information ratio        0.0
# Stability                0.7
# Max Drawdown         -82.0 %
# Sortino ratio           1.09
# Skew                    0.25
# Kurtosis               10.19
# Tail Ratio              1.08
# Common sense ratio      1.26
# Daily value at risk   -5.0 %
# Alpha                   0.36
# Beta                    1.06
# (None, None, None, None, None, None, None, None, None)

# %%
empyrial.orderbook
# Out:
#            2020-12-31  2021-12-31  2022-12-31  2023-08-02
# TSLA          0.00000     0.00000     0.00000     0.00000
# ETH-USD       0.47793     0.24753     0.13122     0.56502
# BTC-USD       0.31694     0.00000     0.00000     0.00000
# AVAX-USD      0.00737     0.05028     0.00090     0.00278
# MATIC-USD     0.00000     0.66738     0.86785     0.43218
# DOT-USD       0.19777     0.03471     0.00000     0.00000
# COIN          0.00000     0.00000     0.00000     0.00000
# XRP-USD       0.00000     0.00000     0.00000     0.00000
# ARKK          0.00000     0.00000     0.00000     0.00000
# AMZN          0.00000     0.00000     0.00000     0.00000
# USD           0.00000     0.00000     0.00000     0.00000

# %% [markdown]
# # Pyfolio reloaded playground

# %%
# pyfolio reloaded playground

# silence warnings
import warnings
warnings.filterwarnings('ignore')
import yfinance as yf
import pyfolio as pf
# %matplotlib inline

# %%
tsla = yf.Ticker('TSLA')
spy = yf.Ticker('SPY')
btc = yf.Ticker('BTC-USD')
tickers = [spy, tsla, btc]
history = spy.history('max')
history.index = history.index.tz_localize('utc')

history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7681 entries, 1993-01-29 00:00:00+00:00 to 2023-08-01 00:00:00+00:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          7681 non-null   float64
#  1   High          7681 non-null   float64
#  2   Low           7681 non-null   float64
#  3   Close         7681 non-null   float64
#  4   Volume        7681 non-null   int64
#  5   Dividends     7681 non-null   float64
#  6   Stock Splits  7681 non-null   int64
# dtypes: float64(5), int64(2)
# memory usage: 480.1 KB

# %%
returns = history.Close.pct_change()

# %%
pf.create_returns_tear_sheet(returns, live_start_date='2020-1-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>1993-01-29</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2023-08-01</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>322</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>42</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>9.7%</td>
#       <td>12.0%</td>
#       <td>10.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>1116.7%</td>
#       <td>49.9%</td>
#       <td>1723.8%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.1%</td>
#       <td>23.5%</td>
#       <td>18.8%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.60</td>
#       <td>0.60</td>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.18</td>
#       <td>0.36</td>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.85</td>
#       <td>0.50</td>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-55.2%</td>
#       <td>-33.7%</td>
#       <td>-55.2%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.12</td>
#       <td>1.12</td>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.86</td>
#       <td>0.83</td>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#       <td>-0.50</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#       <td>9.63</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.94</td>
#       <td>0.94</td>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.2%</td>
#       <td>-2.9%</td>
#       <td>-2.3%</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8144\677551521.py in <module>
# ----> 1 pf.create_returns_tear_sheet(returns, live_start_date='2020-1-1')
#
# c:\Users\LW6412\Anaconda3\envs\dev\lib\site-packages\pyfolio\plotting.py in call_w_context(*args, **kwargs)
#      50         if set_context:
#      51             with plotting_context(), axes_style():
# ---> 52                 return func(*args, **kwargs)
#      53         else:
#      54             return func(*args, **kwargs)
#
# c:\Users\LW6412\Anaconda3\envs\dev\lib\site-packages\pyfolio\tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     502                              header_rows=header_rows)
#     503
# --> 504     plotting.show_worst_drawdown_periods(returns)
#     505
#     506     vertical_sections = 11
#
# c:\Users\LW6412\Anaconda3\envs\dev\lib\site-packages\pyfolio\plotting.py in show_worst_drawdown_periods(returns, top)
#    1662     """
#    1663
# -> 1664     drawdown_df = timeseries.gen_drawdown_table(returns, top=top)
#    1665     utils.print_table(
#    1666         drawdown_df.sort_values('Net drawdown in %', ascending=False),
#
# c:\Users\LW6412\Anaconda3\envs\dev\lib\site-packages\pyfolio\timeseries.py in gen_drawdown_table(returns, top)
#    1006         df_drawdowns.loc[i, 'Peak date'] = (peak.to_pydatetime()
#    1007                                             .strftime('%Y-%m-%d'))
# -> 1008         df_drawdowns.loc[i, 'Valley date'] = (valley.to_pydatetime()
#    1009                                               .strftime('%Y-%m-%d'))
#    1010         if isinstance(recovery, float):
#
# AttributeError: 'numpy.int64' object has no attribute 'to_pydatetime'

# %%
import yfinance as yf
import pandas as pd

# Define the tickers
tickers = ['SPY', 'TSLA', 'BTC-USD']

# %%
# Collect historical data for all tickers
historical_data = {}
for ticker in tickers:
    historical_data[ticker] = yf.download(ticker, start='2018-01-01', end='2023-06-30')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Combine the historical data into a single DataFrame
portfolio_data = pd.concat(historical_data, axis=1)

# %%
# Drop the 'Close' level in the MultiIndex column
portfolio_data.columns = portfolio_data.columns.droplevel()

# %%
# Convert the index to UTC timezone
portfolio_data.index = portfolio_data.index.tz_localize('UTC')

# %%
# Now you can use pyfolio to analyze the entire portfolio
# For example, you can calculate the portfolio returns using the daily returns
daily_returns = portfolio_data['Close'].pct_change().dropna()

# %%
# Convert daily returns Series to a DataFrame
returns_df = pd.DataFrame(daily_returns, columns=['Portfolio'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20032/641167445.py in <module>
#       1 # Convert daily returns Series to a DataFrame
# ----> 2 returns_df = pd.DataFrame(daily_returns, columns=['Portfolio'])
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     607         if isinstance(data, (BlockManager, ArrayManager)):
#     608             mgr = self._init_mgr(
# --> 609                 data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     610             )
#     611
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pandas\core\generic.py in _init_mgr(cls, mgr, axes, dtype, copy)
#     262                 axe = ensure_index(axe)
#     263                 bm_axis = cls._get_block_manager_axis(a)
# --> 264                 mgr = mgr.reindex_axis(axe, axis=bm_axis)
#     265
#     266         # make a copy if explicitly requested
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pandas\core\internals\base.py in reindex_axis(self, new_index, axis, fill_value, consolidate, only_slice)
#      94             copy=False,
#      95             consolidate=consolidate,
# ---> 96             only_slice=only_slice,
#      97         )
#      98
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     668         # some axes don't allow reindexing with dups
#     669         if not allow_dups:
# --> 670             self.axes[axis]._validate_can_reindex(indexer)
#     671
#     672         if axis >= self.ndim:
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pandas\core\indexes\base.py in _validate_can_reindex(self, indexer)
#    3783         # trying to reindex on an axis with duplicates
#    3784         if not self._index_as_unique and len(indexer):
# -> 3785             raise ValueError("cannot reindex from a duplicate axis")
#    3786
#    3787     def reindex(
#
# ValueError: cannot reindex from a duplicate axis

# %%
# Calculate portfolio performance metrics using pyfolio
returns = daily_returns.dropna()
pf.create_full_tear_sheet(returns=returns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20032/1370225679.py in <module>
#       1 # Calculate portfolio performance metrics using pyfolio
#       2 returns = daily_returns.dropna()
# ----> 3 pf.create_full_tear_sheet(returns=returns)
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\tears.py in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     207         turnover_denom=turnover_denom,
#     208         header_rows=header_rows,
# --> 209         set_context=set_context,
#     210     )
#     211
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\plotting.py in call_w_context(*args, **kwargs)
#      48         if set_context:
#      49             with plotting_context(), axes_style():
# ---> 50                 return func(*args, **kwargs)
#      51         else:
#      52             return func(*args, **kwargs)
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     533         bootstrap=bootstrap,
#     534         live_start_date=live_start_date,
# --> 535         header_rows=header_rows,
#     536     )
#     537
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\plotting.py in show_perf_stats(returns, factor_returns, positions, transactions, turnover_denom, live_start_date, bootstrap, header_rows)
#     597         positions=positions,
#     598         transactions=transactions,
# --> 599         turnover_denom=turnover_denom,
#     600     )
#     601
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\timeseries.py in perf_stats(returns, factor_returns, positions, transactions, turnover_denom)
#     734     stats = pd.Series()
#     735     for stat_func in SIMPLE_STAT_FUNCS:
# --> 736         stats[STAT_FUNC_NAMES[stat_func.__name__]] = stat_func(returns)
#     737
#     738     if positions is not None:
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\empyrical\stats.py in calmar_ratio(returns, period, annualization)
#     522
#     523     max_dd = max_drawdown(returns=returns)
# --> 524     if max_dd < 0:
#     525         temp = annual_return(
#     526             returns=returns, period=period, annualization=annualization
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import yfinance as yf
import pandas as pd

# Define the tickers
tickers = ['SPY', 'TSLA', 'BTC-USD']

# Collect historical data for all tickers
historical_data = {}
for ticker in tickers:
    data = yf.download(ticker, start='2018-01-01', end='2023-06-30')
    # Rename columns with the ticker symbol as a prefix
    data.columns = [f"{ticker}_{col}" for col in data.columns]
    historical_data[ticker] = data

# Combine the historical data into a single DataFrame
portfolio_data = pd.concat(historical_data.values(), axis=1)

# Convert the index to UTC timezone
portfolio_data.index = portfolio_data.index.tz_localize('UTC')

# Calculate the daily returns of each asset
daily_returns = portfolio_data['TSLA_Close'].pct_change().dropna()

# Convert daily returns Series to a DataFrame
returns_df = pd.DataFrame(daily_returns, columns=['Portfolio'])

# Replace zero returns with a small non-zero value (e.g., 1e-6) to avoid division by zero
returns_df = returns_df.replace(0, 1e-6)

# Calculate portfolio performance metrics using pyfolio
import pyfolio as pf
pf.create_full_tear_sheet(returns=returns_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20032/3128088010.py in <module>
#      30 # Calculate portfolio performance metrics using pyfolio
#      31 import pyfolio as pf
# ---> 32 pf.create_full_tear_sheet(returns=returns_df)
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\tears.py in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     207         turnover_denom=turnover_denom,
#     208         header_rows=header_rows,
# --> 209         set_context=set_context,
#     210     )
#     211
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\plotting.py in call_w_context(*args, **kwargs)
#      48         if set_context:
#      49             with plotting_context(), axes_style():
# ---> 50                 return func(*args, **kwargs)
#      51         else:
#      52             return func(*args, **kwargs)
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\tears.py in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     533         bootstrap=bootstrap,
#     534         live_start_date=live_start_date,
# --> 535         header_rows=header_rows,
#     536     )
#     537
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\plotting.py in show_perf_stats(returns, factor_returns, positions, transactions, turnover_denom, live_start_date, bootstrap, header_rows)
#     597         positions=positions,
#     598         transactions=transactions,
# --> 599         turnover_denom=turnover_denom,
#     600     )
#     601
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\pyfolio\timeseries.py in perf_stats(returns, factor_returns, positions, transactions, turnover_denom)
#     734     stats = pd.Series()
#     735     for stat_func in SIMPLE_STAT_FUNCS:
# --> 736         stats[STAT_FUNC_NAMES[stat_func.__name__]] = stat_func(returns)
#     737
#     738     if positions is not None:
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\scipy\stats\stats.py in skew(a, axis, bias, nan_policy)
#    1105         return mstats_basic.skew(a, axis, bias)
#    1106
# -> 1107     mean = a.mean(axis, keepdims=True)
#    1108     m2 = _moment(a, 2, axis, mean=mean)
#    1109     m3 = _moment(a, 3, axis, mean=mean)
#
# c:\Users\jclay\anaconda3\envs\blockchain_dev\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     179     if isinstance(ret, mu.ndarray):
#     180         ret = um.true_divide(
# --> 181                 ret, rcount, out=ret, casting='unsafe', subok=False)
#     182         if is_float16_result and out is None:
#     183             ret = arr.dtype.type(ret)
#
# ZeroDivisionError: division by zero
